# %%
from datetime import datetime
from pathlib import Path

# %%
timenow = datetime.now()
year, month, day, hour, minute = (
	timenow.year, timenow.month, timenow.day, timenow.hour, timenow.minute
)

filename = Path("station_info",
						f"year={year}", 
						f"month={month}", 
						f"day={day}", 
						f"{timenow.strftime('%Y%m%d%H%M')}.json ")

# %%
filename
# Out:
# PosixPath('station_info/year=2025/month=10/day=10/202510101748.json ')

# %%
print(datetime.now().timestamp())
# Out:
# 1760133176.333733

# %%
# Get the Unix timestamp as an integer (seconds since epoch)
int(datetime.now().timestamp())
# Out:
# 1760133176
